# %%
# Max Heap

def max_heapify(arr, n, i):
    largest = i
    left = 2 * i + 1
    right = 2 * i + 2

    if left < n and arr[left] > arr[largest]:
        largest = left

    if right < n and arr[right] > arr[largest]:
        largest = right

    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        max_heapify(arr, n, largest)


def max_heap_sort(arr):
    n = len(arr)

    for i in range(n // 2 - 1, -1, -1):
        max_heapify(arr, n, i)

    for i in range(n - 1, 0, -1):
        # Swap root with last element
        arr[0], arr[i] = arr[i], arr[0]

        # Reduce heap size and heapify
        max_heapify(arr, i, 0)


# Input
n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

max_heap_sort(arr)

print("Sorted array in ascending order:", arr)
# Out:
# Enter number of elements: 6
# Enter elements: 10 30 40 20 80 50
# Sorted array in ascending order: [10, 20, 30, 40, 50, 80]

# %%
# Min Heap

def min_heapify(arr, n, i):
    smallest = i
    left = 2 * i + 1
    right = 2 * i + 2

    if left < n and arr[left] < arr[smallest]:
        smallest = left

    if right < n and arr[right] < arr[smallest]:
        smallest = right

    if smallest != i:
        arr[i], arr[smallest] = arr[smallest], arr[i]
        min_heapify(arr, n, smallest)


def min_heap_sort(arr):
    n = len(arr)

    # Build Min Heap
    for i in range(n // 2 - 1, -1, -1):
        min_heapify(arr, n, i)

    # Heap Sort
    for i in range(n - 1, 0, -1):
        # Swap root with last element
        arr[0], arr[i] = arr[i], arr[0]

        # Reduce heap size and heapify
        min_heapify(arr, i, 0)


n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

min_heap_sort(arr)

arr.reverse()

print("Sorted array in ascending order:", arr)
# Out:
# Enter number of elements: 5
# Enter elements: 10 40 30 50
# Sorted array in ascending order: [50, 40, 30, 10]
